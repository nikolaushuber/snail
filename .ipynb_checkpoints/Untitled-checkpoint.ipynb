# %%
from snail import snail_parse
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from snail import snail_parse
#
# ImportError: cannot import name 'snail_parse' from 'snail' (unknown location)
